# %% [markdown]
# # Using MAPE loss function and Powel method builded custom polynomial regression functiion using pipiline(polynomial features - custom linear rergession)
# # In objective function added L2 regularization
# # Polynom degree choose by cross validation

# %%
import numpy as np
from sklearn import datasets

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [20,8]

# %% [markdown]
# ## Get data

# %%
# Generate nonlinear data with outliers.
# Don't hesitate to change the generation parameters, method and data itself! Observe, how it changes results

n_samples = 1000
n_outliers = 100

X, y, coef = datasets.make_regression(n_samples=n_samples, n_features=1,
                                      n_informative=1, noise=25,
                                      coef=True, random_state=1110)

# %%
print(X.shape, y.shape)
# Out:
# (1000, 1) (1000,)

# %%
# Replace first N samples with outliers

X[:n_outliers] = np.random.normal(size=(n_outliers, 1))
y[:n_outliers] = 100 * np.random.normal(size=n_outliers)

# %%
# Add non-linearity to data

y = y+100*X.T[0]*np.sin(X.T[0])

# %%
# Scale data to put in range [0,1] for stability.
# Check results if ignore it.
# See also sklearn User Guide (https://scikit-learn.org/stable/modules/preprocessing.html#scaling-features-to-a-range) and try another tools (Standartization, Normalization)
X = (X - X.min())/(X.max()-X.min())
y = (y - y.min())/(y.max()-y.min())

# %%
#visualize data
plt.plot(X, y, 'o', label = 'Data')
plt.legend()

# %%
# Add bias column to data
X_I = np.c_[np.ones_like(X), X]

# %% [markdown]
# # Loss function - MAPE
# for more information see HW-2-diff-loss-func-and-opt-methods

# %%
def mape(y_true, y_pred):
    y_true = np.asanyarray(y_true)
    y_pred = np.asanyarray(y_pred)
    assert len(y_true) == len(y_pred), "Target and Prediction arrays length should be equal"
    
    if np.any(y_true==0):
        #print("Found zeroes in y_true. MAPE is undefined. Removing it from set.")
        idx = np.where(y_true==0)
        y_true = np.delete(y_true, idx)
        y_pred = np.delete(y_pred, idx)
        #print("%i samples deleted" %len(idx))
    
    mape_value = np.mean(np.abs((y_true - y_pred) / y_true))*100
    return mape_value

# %% [markdown]
# ### Define predict model
# Prediction function $h(\theta|X) = \theta^Tx$:

# %%
def predict(X, theta):
    return np.dot(X, theta)

# %% [markdown]
# # Define objective (goal) function as simple as
# $L(\theta|X,y) = MAPE(y, h(\theta|X))+ (lamda / (2*len(y) )) * np.sum(np.square(theta))$
#
# To make it compatible with optimization procedure, put optimizied parameter _theta_ on the first place in arguments.

# %%
def l1_penalty(theta,lamda):
    return (lamda) * np.sum(np.abs(theta))

# %%
def objective_function(theta, X,y, lamda, loss_function=mape, penalty=l1_penalty):
  y_true = np.asanyarray(y)
  y_pred = predict(X, theta)
  
  return loss_function(y_true, y_pred)+ penalty(theta, lamda)

# %% [markdown]
# # Visualize objective function surface
# # let's see how our objective function surface will look with hight lamda

# %%
size = 100 # amount of tries for each parameter
limits = (-100,100) # range of values for each parameter
error = np.zeros((size,size)) # empty matrix of errors
for i,w in enumerate(np.linspace(*limits,size)): # for each theta[0] component
    for j,b in enumerate(np.linspace(*limits,size)): # for each theate[1] component
        error[i,j] = objective_function(np.array([b,w]), X_I, y, 1000, mape) # compute cost for each theta

# initialize figure
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)

# create 2d array for each index 
K,L = np.meshgrid(np.linspace(*limits,size),np.linspace(*limits,size))

ax.plot_surface(K,L,Z = error, alpha = 0.85) # plot cost function surface in 3d
plt.contour(K,L,error,50, offset = 1) # plot cost function 2d-projection

# %% [markdown]
# ## Train model by Powel method using scipy.optimize

# %%
from scipy import optimize

# %% [markdown]
# lamda = 0

# %%
theta_init = np.array([1]*X_I.shape[1]) # initial value of theta

result = optimize.minimize(
                           objective_function,  # function to optimize. Parameter to optimize should the first argument 
                           args=(X_I, y, 0, mape, l1_penalty), # other arguments of the function
                           x0 = theta_init,     # initial value of parameter to optimize
                           method='Powell',     # optimization method. Try also BFGS, Nelder-Mead, Powell, CG, TNC and others (see docs). Effectivnes can change dramatically!
                           options={}           # arguments of optimization method, like number of iterations, learning rate, etc.
                           )

# %%
without_regul_fun = result.fun
without_regul_theta = result.x
print('Optimization result:', ['FAIL','Success'][result.success])
print('Comment:', result.message)
print('Objective function value:', without_regul_fun)
print('Found theta:', without_regul_theta)
# Out:
# Optimization result: Success
# Comment: Optimization terminated successfully.
# Objective function value: 21.504261381644127
# Found theta: [ 0.41827722 -0.06415804]

# %% [markdown]
# # For further use, let's make universal function to train regression model with any objective and loss functions

# %%
def custom_regression(X, y, lamda,
                      objective_function=objective_function, 
                      loss_function=mape, 
                      init = 1, 
                      verbose = True, 
                      iters = 100, penalty = l1_penalty):
  
    theta_init = np.ones_like(X[0]) * init
    result = optimize.minimize(objective_function,
                             args=(X, y,lamda, loss_function, penalty), 
                             x0 = theta_init, 
                             method='Powell', 
                             options={'maxiter': iters})
    theta = result['x']
    if verbose:
        print(result['fun'])
    return theta

# %% [markdown]
# ## Add polynomial features

# %%
from sklearn.preprocessing import PolynomialFeatures

n = 10 # power of polynom
polynomial_features = PolynomialFeatures(degree=n,include_bias=True) # create instance of preprocessor
X_a = polynomial_features.fit_transform(X) # apply transformation
X_a.shape
# Out:
# (1000, 11)

# %%
theta = custom_regression(X_a, y,1, objective_function=objective_function, loss_function=mape, penalty=l1_penalty)
theta
# Out:
# 18.266555232121654
# array([ 6.33092315e-01, -7.02382482e-01, -4.74805724e-02,  6.43619102e-01,
#         8.53002262e-02,  3.53581663e-01, -3.27872677e-07, -1.14647026e-06,
#        -8.74897300e-07, -1.23229225e-07, -9.29107846e-08])

# %%
y_pred = predict(X_a, theta)
plt.plot(X, y, 'o', label = 'Data')
ax = plt.gca()
ax.autoscale(enable = True)
plt.plot(X, y_pred, '.', label = 'Prediction')
plt.legend()

# %% [markdown]
# # Visually difficult to undestend if polynom with power 10 good or bad for our data, choosen optimization method and loss. For first evaluating we will use splitting data on train adn test to see how our model behave on data that it didn't see before using train and test score

# %%
from sklearn.model_selection import train_test_split

# Split data to test and train in sklearn style
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %% [markdown]
# PolynomialFeatures(degree=10
# lamda for linear regression = 10

# %%
results = {}
lamda=10
polynomial_features = PolynomialFeatures(degree=10,include_bias=True) # create instance of preprocessor

X_a_train = polynomial_features.fit_transform(X_train)
X_a_test = polynomial_features.fit_transform(X_test)

theta = custom_regression(X_a, y,10, objective_function=objective_function, loss_function=mape, penalty = l1_penalty)

test_score = objective_function(theta=theta, X=X_a_test, y=y_test, lamda=lamda)
train_score = objective_function(theta=theta, X=X_a_train, y=y_train, lamda=lamda)
results[lamda] ={'test_score':test_score, 'train_score':train_score}
# Out:
# 25.39616253925407

# %%
import pandas as pd
results = pd.DataFrame(results).T
results.style
# Out:
# <style  type="text/css" >
# </style><table id="T_726a1a08_84f4_11eb_bfb1_0c7a151cdcce" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >test_score</th>        <th class="col_heading level0 col1" >train_score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_726a1a08_84f4_11eb_bfb1_0c7a151cdccelevel0_row0" class="row_heading level0 row0" >10</th>
#                         <td id="T_726a1a08_84f4_11eb_bfb1_0c7a151cdccerow0_col0" class="data row0 col0" >25.045403</td>
#                         <td id="T_726a1a08_84f4_11eb_bfb1_0c7a151cdccerow0_col1" class="data row0 col1" >25.569183</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Let's use different lamdas

# %%
# %%time
results = {}
lamda_list=np.arange(0, 1, 0.1)
for i,lamda in enumerate(lamda_list):
  polynomial_features = PolynomialFeatures(degree=10,include_bias=True)
  
  # make transformation of all data subsets
  X_all = polynomial_features.fit_transform(X)
  X_a_train = polynomial_features.fit_transform(X_train)
  X_a_test = polynomial_features.fit_transform(X_test)
  
  # train model
  theta = custom_regression(X_a_train, y_train, objective_function=objective_function, loss_function=mape, iters = 100, lamda = n)
  
  # test model
#   y_pred_test = predict(X_a_test, theta)
#   y_pred_train = predict(X_a_train, theta)
  test_score = objective_function(theta=theta, X=X_a_test, y=y_test, lamda=lamda)
  train_score = objective_function(theta=theta, X=X_a_train, y=y_train, lamda=lamda)

  results[lamda] ={'test_score':test_score, 'train_score':train_score}
    
  #visualize results
  y_pred = predict(X_all, theta)
  
  ax = plt.subplot(1, len(lamda_list), i + 1)
  ax.plot(X, y, '.', alpha = 0.5, label = 'Data')
  ax.autoscale(enable = False)
  ax.plot(X, y_pred, 'o', label = 'Prediction')
  plt.title("Lamda %i\nTrain Score: %.2f \nTest Score: %.2f"%(lamda_list[i], train_score, test_score))
plt.legend()
# Out:
# 28.779626845749398
# 28.779626845749398
# 28.779626845749398
# 28.779626845749398
# 28.779626845749398
# 28.779626845749398
# 28.779626845749398
# 28.779626845749398
# 28.779626845749398
# 28.779626845749398
# Wall time: 1.57 s

# %%
results = pd.DataFrame(results).T
results.style.highlight_min()
# Out:
# <style  type="text/css" >
#     #T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow0_col0 {
#             background-color:  yellow;
#         }    #T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow0_col1 {
#             background-color:  yellow;
#         }</style><table id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdcce" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >test_score</th>        <th class="col_heading level0 col1" >train_score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row0" class="row_heading level0 row0" >0.0</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow0_col0" class="data row0 col0" >22.779409</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow0_col1" class="data row0 col1" >23.319739</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row1" class="row_heading level0 row1" >0.1</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow1_col0" class="data row1 col0" >22.834008</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow1_col1" class="data row1 col1" >23.374338</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row2" class="row_heading level0 row2" >0.2</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow2_col0" class="data row2 col0" >22.888607</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow2_col1" class="data row2 col1" >23.428937</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row3" class="row_heading level0 row3" >0.30000000000000004</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow3_col0" class="data row3 col0" >22.943206</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow3_col1" class="data row3 col1" >23.483536</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row4" class="row_heading level0 row4" >0.4</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow4_col0" class="data row4 col0" >22.997805</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow4_col1" class="data row4 col1" >23.538135</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row5" class="row_heading level0 row5" >0.5</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow5_col0" class="data row5 col0" >23.052404</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow5_col1" class="data row5 col1" >23.592734</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row6" class="row_heading level0 row6" >0.6000000000000001</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow6_col0" class="data row6 col0" >23.107003</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow6_col1" class="data row6 col1" >23.647332</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row7" class="row_heading level0 row7" >0.7000000000000001</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow7_col0" class="data row7 col0" >23.161601</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow7_col1" class="data row7 col1" >23.701931</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row8" class="row_heading level0 row8" >0.8</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow8_col0" class="data row8 col0" >23.216200</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow8_col1" class="data row8 col1" >23.756530</td>
#             </tr>
#             <tr>
#                         <th id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccelevel0_row9" class="row_heading level0 row9" >0.9</th>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow9_col0" class="data row9 col0" >23.270799</td>
#                         <td id="T_73c5615a_84f4_11eb_9d9a_0c7a151cdccerow9_col1" class="data row9 col1" >23.811129</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # By test score better use lamda = 0.7, but for more stable result we need to use GridSearchCV for our custom function
# ### firstly we will use GridSearchCV for sklearn Ridge LR

# %%
from numpy import arange
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline


steps = [
    ('poly', PolynomialFeatures(degree=10)),
    ('model', Lasso())
]

ridge_pipe = Pipeline(steps)

# Applying Grid Search to find the best model and the best parameters
from sklearn.model_selection import GridSearchCV

parameters = [ {'model__alpha': np.arange(0, 1, 0.1) } ]

from sklearn.metrics import fbeta_score, make_scorer
scoring_func = make_scorer(mape)
grid_search = GridSearchCV(estimator = ridge_pipe, 
                           param_grid = parameters,
                           scoring = scoring_func,
                           cv = 5,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)  # <-- GETTING ERROR IN HERE
# summarize
print('MAPe: %.3f' % grid_search.best_score_)
print('Config: %s' % grid_search.best_params_)
# Out:
# MAPe: 24.158
# Config: {'model__alpha': 0.1}

# %%
# grid_search.cv_results_

# %% [markdown]
# # For estimating lamda for regularization and for better generalization we need to do cross validation

# %% [markdown]
# To make convenient and safe using of our approach (preprocessing + modelling) we can use great sklearn tool called [Pipelines](https://scikit-learn.org/stable/modules/compose.html#pipelines-and-composite-estimators).
#
# Pipeline can include any number of data transformations and modelling, and than be treated as a single sklearn object.
#
# To make it possible, all models of sklearn inherits the same interface, which essentialy should have just few methods:
# * ```__init__()```, that should be able to be called without arguments and create an instance with no dependencies to data.
# * ```fit()```, that takes data and make all data-dependent actions (transformations or training). Main logic is here.
# * ```predict()``` (for models) or ```transform()``` (for preprocessing) to process a new data after fitted
#
# Optionally, we can use ```score()``` which take true data and return single value to evaluate quality of the model. It is used to make cross-validation and other model selection procedures.
#
# Finally, methods ```fit_transform()``` or ```fit_predict()``` are not essential, but commonly used and just make fit and transform (or predict) on the same data data in one step.

# %%
from sklearn.model_selection import cross_val_score

from sklearn.base import BaseEstimator, RegressorMixin

# %% [markdown]
# Sklearn has one basic class ```BaseEstimator``` for all objects and few inherited specials for particular tasks, like ```ClassifierMixin```, ```RegressorMixin``` and ```TransformerMixin```. Inheriting them we can be sure that we have all non-essential but useful methods, like ```set_value```, ```get_value``` etc, and also tell Pipelines how to treat our object.

# %%
class CustomRegression(BaseEstimator, RegressorMixin):                           
  def __init__(self, loss_function=mape, objective_function=objective_function, lamda=0): # all arguments should have default values
    self.theta = None # we don't know shape of theta on this stage
    # just save all variables taken during call to internal variables
    self.loss_function = loss_function 
    self.objective_function = objective_function
    self.lamda = lamda
    
  def predict(self, X):
    return predict(X, self.theta)
  
  def score(self, X, y):
    return self.objective_function(theta=self.theta, X=X,y=y,lamda=self.lamda,loss_function=self.loss_function)
  
  def fit(self, X, y):
    if type(self.theta) == type(None):
      self.theta = np.ones_like(X[0])
    else:
      assert self.theta.shape == X[0].shape, "Model's shape doesn't fit input shape"
    self.theta = custom_regression(X, y, self.lamda, self.objective_function, self.loss_function, verbose = False)
    return self.score(X, y)
  
  def fit_predict(self, X, y):
    self.fit(X,y)
    return self.predict(X)

# %%
# %%time
results = {}
row_results = {}
for i,n in enumerate(lamda_list):
  polynomial_features = PolynomialFeatures(degree = 10, include_bias=True) # create instance of transformer
  regression = CustomRegression(lamda=n) # create instance of model
    
  # make pipeline as list of pairs (<stage name>, <stage object>):
  pipeline = Pipeline([("polynomial_features", polynomial_features), # augment data
                       ("linear_regression", regression)]) # apply linear regression

  # Evaluate pipeline using crossvalidation and score() method
  scores = cross_val_score(pipeline, X_train, y_train, cv=10)
    
  pipeline.fit(X_train, y_train)
  # Make single evaluation on test set
  test_scores = pipeline.score(X_test, y_test)

  # Save results
  results[n] = {'CV_mean':scores.mean(), 'CV_std':scores.std(), 'Test':test_scores}
  row_results[n] = scores

  # Plot results
  line_x = np.linspace(-0.1, 1.1, 1000).reshape(1000,1)
  line_y = pipeline.predict(line_x)
  
  ax = plt.subplot(1, len(lamda_list), i + 1)
  ax.plot(X, y, '.', alpha = 0.5, label = 'Data')
  ax.autoscale(enable = False)
  ax.plot(line_x, line_y, '-', label = 'Prediction')
  plt.title("Lamda %i\nCV-Score: %.2f +- %.2f\nTest-Score: %.2f"%(n, results[n]['CV_mean'],results[n]['CV_std'],results[n]['Test']))
  
plt.legend()
# Out:
# Wall time: 31.6 s

# %%
results = pd.DataFrame(results).T
results.style.highlight_min()
# Out:
# <style  type="text/css" >
#     #T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow0_col0 {
#             background-color:  yellow;
#         }    #T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow0_col1 {
#             background-color:  yellow;
#         }    #T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow0_col2 {
#             background-color:  yellow;
#         }</style><table id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdcce" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CV_mean</th>        <th class="col_heading level0 col1" >CV_std</th>        <th class="col_heading level0 col2" >Test</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row0" class="row_heading level0 row0" >0.0</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow0_col0" class="data row0 col0" >12.870903</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow0_col1" class="data row0 col1" >3.677823</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow0_col2" class="data row0 col2" >12.584177</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row1" class="row_heading level0 row1" >0.1</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow1_col0" class="data row1 col0" >13.856469</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow1_col1" class="data row1 col1" >3.697155</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow1_col2" class="data row1 col2" >13.545674</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row2" class="row_heading level0 row2" >0.2</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow2_col0" class="data row2 col0" >14.614306</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow2_col1" class="data row2 col1" >3.712663</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow2_col2" class="data row2 col2" >14.291606</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row3" class="row_heading level0 row3" >0.30000000000000004</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow3_col0" class="data row3 col0" >15.295934</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow3_col1" class="data row3 col1" >3.811967</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow3_col2" class="data row3 col2" >14.818069</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row4" class="row_heading level0 row4" >0.4</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow4_col0" class="data row4 col0" >15.946062</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow4_col1" class="data row4 col1" >3.718718</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow4_col2" class="data row4 col2" >15.372652</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row5" class="row_heading level0 row5" >0.5</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow5_col0" class="data row5 col0" >16.308735</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow5_col1" class="data row5 col1" >3.894934</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow5_col2" class="data row5 col2" >15.870370</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row6" class="row_heading level0 row6" >0.6000000000000001</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow6_col0" class="data row6 col0" >16.851112</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow6_col1" class="data row6 col1" >3.887937</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow6_col2" class="data row6 col2" >16.304933</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row7" class="row_heading level0 row7" >0.7000000000000001</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow7_col0" class="data row7 col0" >17.390119</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow7_col1" class="data row7 col1" >4.065043</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow7_col2" class="data row7 col2" >17.281913</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row8" class="row_heading level0 row8" >0.8</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow8_col0" class="data row8 col0" >17.928539</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow8_col1" class="data row8 col1" >3.885180</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow8_col2" class="data row8 col2" >17.076605</td>
#             </tr>
#             <tr>
#                         <th id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccelevel0_row9" class="row_heading level0 row9" >0.9</th>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow9_col0" class="data row9 col0" >18.363730</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow9_col1" class="data row9 col1" >4.111425</td>
#                         <td id="T_87bc8eca_84f4_11eb_99ab_0c7a151cdccerow9_col2" class="data row9 col2" >17.787946</td>
#             </tr>
#     </tbody></table>

# %%
# %%time
results = {}
row_results = {}
for i,n in enumerate(np.logspace(-10, 1, 10)):
  polynomial_features = PolynomialFeatures(degree = 10, include_bias=True) # create instance of transformer
  regression = CustomRegression(lamda=n) # create instance of model
    
  # make pipeline as list of pairs (<stage name>, <stage object>):
  pipeline = Pipeline([("polynomial_features", polynomial_features), # augment data
                       ("linear_regression", regression)]) # apply linear regression

  # Evaluate pipeline using crossvalidation and score() method
  scores = cross_val_score(pipeline, X_train, y_train, cv=10)
    
  pipeline.fit(X_train, y_train)
  # Make single evaluation on test set
  test_scores = pipeline.score(X_test, y_test)

  # Save results
  results[n] = {'CV_mean':scores.mean(), 'CV_std':scores.std(), 'Test':test_scores}
  row_results[n] = scores
# Out:
# Wall time: 22.8 s

# %%
np.logspace(-10, 1, 10)[4]
# Out:
# 7.742636826811277e-06

# %%
results = pd.DataFrame(results).T
results.style.highlight_min()
# Out:
# <style  type="text/css" >
#     #T_95589346_84f4_11eb_93b8_0c7a151cdccerow3_col2 {
#             background-color:  yellow;
#         }    #T_95589346_84f4_11eb_93b8_0c7a151cdccerow4_col0 {
#             background-color:  yellow;
#         }    #T_95589346_84f4_11eb_93b8_0c7a151cdccerow6_col1 {
#             background-color:  yellow;
#         }</style><table id="T_95589346_84f4_11eb_93b8_0c7a151cdcce" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CV_mean</th>        <th class="col_heading level0 col1" >CV_std</th>        <th class="col_heading level0 col2" >Test</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row0" class="row_heading level0 row0" >1e-10</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow0_col0" class="data row0 col0" >12.868635</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow0_col1" class="data row0 col1" >3.676876</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow0_col2" class="data row0 col2" >12.587162</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row1" class="row_heading level0 row1" >1.6681005372000556e-09</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow1_col0" class="data row1 col0" >12.866471</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow1_col1" class="data row1 col1" >3.682916</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow1_col2" class="data row1 col2" >12.584139</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row2" class="row_heading level0 row2" >2.782559402207126e-08</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow2_col0" class="data row2 col0" >12.865837</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow2_col1" class="data row2 col1" >3.683285</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow2_col2" class="data row2 col2" >12.584142</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row3" class="row_heading level0 row3" >4.641588833612782e-07</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow3_col0" class="data row3 col0" >12.870338</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow3_col1" class="data row3 col1" >3.677183</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow3_col2" class="data row3 col2" >12.567892</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row4" class="row_heading level0 row4" >7.742636826811277e-06</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow4_col0" class="data row4 col0" >12.865029</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow4_col1" class="data row4 col1" >3.682966</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow4_col2" class="data row4 col2" >12.572654</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row5" class="row_heading level0 row5" >0.00012915496650148855</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow5_col0" class="data row5 col0" >12.870201</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow5_col1" class="data row5 col1" >3.682498</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow5_col2" class="data row5 col2" >12.573303</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row6" class="row_heading level0 row6" >0.002154434690031887</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow6_col0" class="data row6 col0" >12.890325</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow6_col1" class="data row6 col1" >3.672431</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow6_col2" class="data row6 col2" >12.598561</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row7" class="row_heading level0 row7" >0.0359381366380464</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow7_col0" class="data row7 col0" >13.267286</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow7_col1" class="data row7 col1" >3.688031</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow7_col2" class="data row7 col2" >12.919768</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row8" class="row_heading level0 row8" >0.5994842503189421</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow8_col0" class="data row8 col0" >16.790626</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow8_col1" class="data row8 col1" >3.865169</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow8_col2" class="data row8 col2" >16.611355</td>
#             </tr>
#             <tr>
#                         <th id="T_95589346_84f4_11eb_93b8_0c7a151cdccelevel0_row9" class="row_heading level0 row9" >10.0</th>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow9_col0" class="data row9 col0" >27.069242</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow9_col1" class="data row9 col1" >3.852972</td>
#                         <td id="T_95589346_84f4_11eb_93b8_0c7a151cdccerow9_col2" class="data row9 col2" >28.239297</td>
#             </tr>
#     </tbody></table>

# %%
polynomial_features = PolynomialFeatures(degree = 10, include_bias=True) # create instance of transformer
regression = CustomRegression(lamda=np.logspace(-10, 1, 10)[4]) # create instance of model

pipeline = Pipeline([("polynomial_features", polynomial_features), # augment data
                       ("linear_regression", regression)]) # apply linear regression

pipeline.fit(X_train, y_train)
  # Make single evaluation on test set
test_scores = pipeline.score(X_test, y_test)
# pipeline.predict(X_test, y_test)

# %%
y_pred = pipeline.predict(X)
plt.plot(X, y, 'o', label = 'Data')
ax = plt.gca()
ax.autoscale(enable = True)
plt.plot(X, y_pred, '.', label = 'Prediction')
plt.legend()

# %% [markdown]
# ## Question is why lamda/alpha = 0 is better here(or almost = 0)? because polynomial features?

# %% [markdown]
# # If we use Ridge regression for data without polynomial featuring we can estimate alpha(lamda) using yellowbrick.regressor.AlphaSelection

# %% [markdown]
# Estimators with Built-in Cross-Validation
# RidgeCV uses Leave-One-Out Cross-Validation

# %%
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection

# %%
alphas = np.logspace(-10, 1, 400)
print(alphas.shape)
# Out:
# (400,)

# %%
model = LassoCV(alphas=alphas)
visualizer = AlphaSelection(model)
visualizer.fit(X, y)
visualizer.show()

# %% [markdown]
# #### for data without polynomial featuring alpha(lamda) = 0
